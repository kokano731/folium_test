# %%
# Python: foliumでJupyter Notebookに地図を描画する
# https://ohke.hateblo.jp/entry/2018/03/02/230000

import folium

chiba_map = folium.Map(location=[35.607451, 140.106340])

chiba_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbf71cdaf367e81bc9472b27657d3113 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbf71cdaf367e81bc9472b27657d3113&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbf71cdaf367e81bc9472b27657d3113 = L.map(
#                 &quot;map_bbf71cdaf367e81bc9472b27657d3113&quot;,
#                 {
#                     center: [35.607451, 140.10634],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e46a2af432a8ea33ea1cacb1f53f6dcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e46a2af432a8ea33ea1cacb1f53f6dcd.addTo(map_bbf71cdaf367e81bc9472b27657d3113);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

chiba_cities = pd.DataFrame({
    'city': ['千葉市', '館山市', '銚子市', '浦安市'],
    'latitude': [35.607451, 34.996596, 35.734795, 35.653146],
    'longtude': [140.106340, 139.869906, 140.826926, 139.902058],
    'population': [975535, 46349, 61674, 168169]
})

chiba_map = folium.Map(location=[35.607451, 140.106340], zoom_start=9)

for i, r in chiba_cities.iterrows():
    folium.Marker(location=[r['latitude'], r['longtude']], popup=r['city']).add_to(chiba_map)
    
chiba_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f1ebbad871edbe975ba283f3d4a3e2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f1ebbad871edbe975ba283f3d4a3e2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f1ebbad871edbe975ba283f3d4a3e2e = L.map(
#                 &quot;map_4f1ebbad871edbe975ba283f3d4a3e2e&quot;,
#                 {
#                     center: [35.607451, 140.10634],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_229410f966222b64b80119a35a2d32c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_229410f966222b64b80119a35a2d32c2.addTo(map_4f1ebbad871edbe975ba283f3d4a3e2e);
#
#
#             var marker_0db275454f1fb256e31d816faa40e5d3 = L.marker(
#                 [35.607451, 140.10634],
#                 {}
#             ).addTo(map_4f1ebbad871edbe975ba283f3d4a3e2e);
#
#
#         var popup_5d650e9489c84eb830f2317d679f50a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51d6d4c6279ac565abb076275b1e210c = $(`&lt;div id=&quot;html_51d6d4c6279ac565abb076275b1e210c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;千葉市&lt;/div&gt;`)[0];
#                 popup_5d650e9489c84eb830f2317d679f50a3.setContent(html_51d6d4c6279ac565abb076275b1e210c);
#
#
#
#         marker_0db275454f1fb256e31d816faa40e5d3.bindPopup(popup_5d650e9489c84eb830f2317d679f50a3)
#         ;
#
#
#
#
#             var marker_26c2f7825dc2cdc7704c291c16266036 = L.marker(
#                 [34.996596, 139.869906],
#                 {}
#             ).addTo(map_4f1ebbad871edbe975ba283f3d4a3e2e);
#
#
#         var popup_64fd08ff45117d918b194a34866584a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac6d1faf9eec9792e182ebab8d110cf3 = $(`&lt;div id=&quot;html_ac6d1faf9eec9792e182ebab8d110cf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;館山市&lt;/div&gt;`)[0];
#                 popup_64fd08ff45117d918b194a34866584a4.setContent(html_ac6d1faf9eec9792e182ebab8d110cf3);
#
#
#
#         marker_26c2f7825dc2cdc7704c291c16266036.bindPopup(popup_64fd08ff45117d918b194a34866584a4)
#         ;
#
#
#
#
#             var marker_19d661aa4ade5224e1296e1614995687 = L.marker(
#                 [35.734795, 140.826926],
#                 {}
#             ).addTo(map_4f1ebbad871edbe975ba283f3d4a3e2e);
#
#
#         var popup_f29647ad51ff6a4be224bec6a425635c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0fe11507425e2b2123c1c44b1787d37b = $(`&lt;div id=&quot;html_0fe11507425e2b2123c1c44b1787d37b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;銚子市&lt;/div&gt;`)[0];
#                 popup_f29647ad51ff6a4be224bec6a425635c.setContent(html_0fe11507425e2b2123c1c44b1787d37b);
#
#
#
#         marker_19d661aa4ade5224e1296e1614995687.bindPopup(popup_f29647ad51ff6a4be224bec6a425635c)
#         ;
#
#
#
#
#             var marker_141efd344654d925353dcc254dfb2aed = L.marker(
#                 [35.653146, 139.902058],
#                 {}
#             ).addTo(map_4f1ebbad871edbe975ba283f3d4a3e2e);
#
#
#         var popup_61e2ace1b157a5b092c13dcead450a19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c9c6edccf3e0bda56cd45f2147b3952 = $(`&lt;div id=&quot;html_0c9c6edccf3e0bda56cd45f2147b3952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;浦安市&lt;/div&gt;`)[0];
#                 popup_61e2ace1b157a5b092c13dcead450a19.setContent(html_0c9c6edccf3e0bda56cd45f2147b3952);
#
#
#
#         marker_141efd344654d925353dcc254dfb2aed.bindPopup(popup_61e2ace1b157a5b092c13dcead450a19)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
